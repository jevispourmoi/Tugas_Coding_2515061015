# %%
import torch

# %%
#selesaikan soal berikut
#what is the transpose of this vector below?
x = torch.tensor([[25], [2], [-3], [-23]])
x
# Out:
# tensor([[ 25],
#         [  2],
#         [ -3],
#         [-23]])

# %%
x.T
print("transpose dari vector tersebut adalah:", x.T)
# Out:
# transpose dari vector tersebut adalah: tensor([[ 25,   2,  -3, -23]])
