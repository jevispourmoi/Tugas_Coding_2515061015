# %%
import numpy as py

# %%
#buat vector i dengan elemen (1, 0)
i = py.array([1, 0])
print("vector i =", i)
# Out:
# vector i = [1 0]

# %%
#dan vector j dengan elemen (0, 1)
j = py.array([0, 1])
print("vector j =", j)
# Out:
# vector j = [0 1]

# %%
#buktikan apakah vector i dan j itu orthogonal
py.dot(i, j)
# Out:
# np.int64(0)
