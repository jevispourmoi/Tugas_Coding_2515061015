# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x = 15

# %%
# tampilkan tipe data dari x
(type(x))

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y = 51

# %%
# tampilkan tipe data dari y
(type(y))

# %%
# jumlahkan x+y
print(x+y)

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 1.5

# %%
# jumlahkan x_float dengan y
(print(x_float+y))

# %%
# tampilkan tipe data dari x_float
(type(x_float))

# %%
 # lakukan tahapan pada soal 1 dengan menggunakan tensor flow
import tensorflow as tf

# %%
x_tf = tf.Variable(15, dtype=tf.int16)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=15>

# %%
x_tf.shape
# Out:
# TensorShape([])

# %%
y_tf = tf.Variable(51, dtype=tf.int16)
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=51>

# %%
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=66>

# %%
tf_sum = tf.add(x_tf, y_tf)
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=66>

# %%
tf_sum.numpy()

# %%
type(tf_sum.numpy())

# %%
tf_float = tf.Variable(1.5, dtype=tf.float16)
tf_float
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float16, numpy=1.5>
